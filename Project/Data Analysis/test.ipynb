# %%
import pandas as pd
import os
openpath = 'C:/Users/ad/Documents/카카오톡 받은 파일/fin/'


def auto(): # file_list에는 파일 이름과 확장자만 저장
  file_list = os.listdir(openpath)
  name_list = []
  for file_name in file_list:
    if ".xlsx" in file_name:
        openfilename = openpath + file_name  
        name_list.append(file_name) # name_list에는 파일경로 및 이름까지 저장

  for file in name_list:
      RENAME_ALL = {'pm25':'pm2.5',
                    '평균기온(°C)':'mean temperature(°C)',
                    '일강수량(mm)':'daily precipitation(mm)',
                    '평균 풍속(m/s)':'mean wind speed', 
                    '평균 상대습도(%)':'average relatively humidity(%)'} 
      tmp = pd.read_excel(openfilename)
      print(tmp.columns)


      tmp.rename(RENAME_ALL, axis='columns', inplace=True)
      print(tmp.columns)
      savepath = f'C:/Users/ad/Desktop/test/test/{file}'
      tmp.to_excel(savepath, index=False)
      print(file)
      print(savepath)
      

'''
기존코드 
 file_name = path + file_name
(중략)
tmp.to_excel('C:/Users/admin/Desktop/last/file_name')
결과값중략)
tmp.to_excel('C:/Users/admin/Desktop/last/file_name')
결과값
'C:/Users/admin/Desktop/last/file_nameC:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx'
충돌이 납니다.

기존코드

   tmp.rename(columns={'pm25':'pm2.5', 
                        '평균기온(°C)':'mean temperature(°C)', 
                        '일강수량(mm)':'daily precipitation(mm)',
                        '평균 풍속(m/s)':'mean wind speed', 
                        '평균 상대습도(%)':'average relatively humidity(%)' 
                        })
가독성이 좋지않아 분할해주고
axis로 컬럼에대한 명시를 해야합니다.

저렇게하면 tmp 컬럼을 바꾼 복사본만 생깁니다. 
즉 tmp = ~ 하던지
inplace=True(원본을 바꾼다) 옵션을 줘야 됩니다.

'''
# Out:
# "\n기존코드 \n file_name = path + file_name\n(중략)\ntmp.to_excel('C:/Users/admin/Desktop/last/file_name')\n결과값중략)\ntmp.to_excel('C:/Users/admin/Desktop/last/file_name')\n결과값\n'C:/Users/admin/Desktop/last/file_nameC:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx'\n충돌이 납니다.\n\n기존코드\n\n   tmp.rename(columns={'pm25':'pm2.5', \n                        '평균기온(°C)':'mean temperature(°C)', \n                        '일강수량(mm)':'daily precipitation(mm)',\n                        '평균 풍속(m/s)':'mean wind speed', \n                        '평균 상대습도(%)':'average relatively humidity(%)' \n                        })\n가독성이 좋지않아 분할해주고\naxis로 컬럼에대한 명시를 해야합니다.\n"

# %%
# 최종파일 오픈
def finalopen(a):
    filepath = f'C:/Users/ad/Desktop/test/fin/{a}FIN.xlsx'
    excel_df = pd.read_excel(filepath)
    print (filepath)
    return(excel_df)
    
columns = ['SEOUL', 'PUSAN', 'DEAGU', 'INCHEON', 'KWANG_JU', 'DAEJEON', 'ULSAN',
       'KYEONG_GI', 'KANGONE', 'CHUNG_BUK', 'CHUNG_NAM', 'JEON_BUK',
       'JEON_NAM', 'KYUNG_BUK', 'KYUNG_NAM', 'JE_JU', 'SEJONG']

for column in columns:
     globals()[f'{column}FINAL'] = finalopen(column)

# 각각 파일은 column에있는명 + FINAL (ex: SEOULFINAL)로 데이터프레임 만들어짐
# Out:
# C:/Users/ad/Desktop/test/fin/SEOULFIN.xlsx
# C:/Users/ad/Desktop/test/fin/PUSANFIN.xlsx
# C:/Users/ad/Desktop/test/fin/DEAGUFIN.xlsx
# C:/Users/ad/Desktop/test/fin/INCHEONFIN.xlsx
# C:/Users/ad/Desktop/test/fin/KWANG_JUFIN.xlsx
# C:/Users/ad/Desktop/test/fin/DAEJEONFIN.xlsx
# C:/Users/ad/Desktop/test/fin/ULSANFIN.xlsx
# C:/Users/ad/Desktop/test/fin/KYEONG_GIFIN.xlsx
# C:/Users/ad/Desktop/test/fin/KANGONEFIN.xlsx
# C:/Users/ad/Desktop/test/fin/CHUNG_BUKFIN.xlsx
# C:/Users/ad/Desktop/test/fin/CHUNG_NAMFIN.xlsx
# C:/Users/ad/Desktop/test/fin/JEON_BUKFIN.xlsx
# C:/Users/ad/Desktop/test/fin/JEON_NAMFIN.xlsx
# C:/Users/ad/Desktop/test/fin/KYUNG_BUKFIN.xlsx
# C:/Users/ad/Desktop/test/fin/KYUNG_NAMFIN.xlsx
# C:/Users/ad/Desktop/test/fin/JE_JUFIN.xlsx
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx

# %%
import pandas as pd
import folium
import json

# %%
testbusanmap = folium.Map(
    location = [35.20310343924181, 129.0570605554762],
    titles = 'Pusan map',
    zoom_start = 11
)

# %%
testbusanmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_036b4e9b0f3747f0a5c6087910f95120%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_036b4e9b0f3747f0a5c6087910f95120%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_036b4e9b0f3747f0a5c6087910f95120%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_036b4e9b0f3747f0a5c6087910f95120%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.20310343924181%2C%20129.0570605554762%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
SEOULFINAL.PM10
# Out:
# 0      20
# 1      41
# 2      51
# 3      42
# 4      17
#        ..
# 443    47
# 444    68
# 445    56
# 446    39
# 447    69
# Name: PM10, Length: 448, dtype: int64

# %%
SEOULFINAL.PM10
# Out:
# 0      20
# 1      41
# 2      51
# 3      42
# 4      17
#        ..
# 443    47
# 444    68
# 445    56
# 446    39
# 447    69
# Name: PM10, Length: 448, dtype: int64

# %%
lat = wd.loc[1, 'PM10']
lat
# Out:
# 41

# %%
wd =  pd.DataFrame({'위도':[35.20310343924181],'경도':[129.0570605554762]})

# %%
wd
# Out:
#           위도          경도
# 0  35.203103  129.057061

# %%
ㅇ

# %%
folium.CircleMarker(
    location     = [35.203103,129.057061],
    fill         = True,
    fill_color   = 'red', 
    fill_opacity = 1,
    color        = 'red',
    weight       = 10,
    radius       = 30,
).add_to(testbusanmap)

# %%
testbusanmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_036b4e9b0f3747f0a5c6087910f95120%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_036b4e9b0f3747f0a5c6087910f95120%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_036b4e9b0f3747f0a5c6087910f95120%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_036b4e9b0f3747f0a5c6087910f95120%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.20310343924181%2C%20129.0570605554762%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import pandas as pd
import folium
import json

testbusanmap = folium.Map(
    location = [35.20310343924181, 129.0570605554762],
    titles = 'Pusan map',
    zoom_start = 11
)

folium.CircleMarker(
    location     = [35.203103,129.057061],
    fill         = True,
    fill_color   = 'red', 
    fill_opacity = 1,
    color        = 'red',
    weight       = 10,
    radius       = 30,
).add_to(testbusanmap)

# %%
testbusanmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c6f9723bd0374f27bcdb1d5dd5cf4585%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c6f9723bd0374f27bcdb1d5dd5cf4585%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c6f9723bd0374f27bcdb1d5dd5cf4585%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c6f9723bd0374f27bcdb1d5dd5cf4585%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.20310343924181%2C%20129.0570605554762%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import pandas as pd
import os
openpath = 'C:/Users/ad/Documents/카카오톡 받은 파일/fin/'
file_list = os.listdir(openpath)
name_list = []
for file_name in file_list:
    if ".xlsx" in file_name:
        openfilename = openpath + file_name  
        excel_df = pd.read_excel(openfilename)
        #print(openfilename)
        for i in openfilename:
            x = i.split('/')
            filename = x[-1].replace('.xlsx', '')
            #print(filename)
            globals()[f'{column}FINAL'] = finalopen(column)
            #print(f'{column}FINAL')
# Out:
# 38.5
#
# [448 rows x 11 columns]
# U
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# L
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# S
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# A
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# N
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# F
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# I
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# N
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# .
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# x
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# l
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# s
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]
# x
# C:/Users/ad/Desktop/test/fin/SEJONGFIN.xlsx
#            DATE  PM10  PM2.5   CO    NO2     O3    SO2  CENTIGRADE  \
# 0    2021-06-22    27     16  0.5  0.016  0.025  0.004        23.2
# 1    2021-06-21    37     20  0.5  0.011  0.067  0.004        23.2
# 2    2021-06-20    38     19  0.5  0.007  0.064  0.004        23.2
# 3    2021-06-19    29     14  0.4  0.008  0.050  0.003        22.2
# 4    2021-06-18    12      4  0.4  0.008  0.031  0.003        20.6
# ..          ...   ...    ...  ...    ...    ...    ...         ...
# 443  2020-04-05    39     14  0.4  0.010  0.042  0.003         7.7
# 444  2020-04-04    74     25  0.4  0.013  0.043  0.003         8.5
# 445  2020-04-03    50     28  0.4  0.019  0.042  0.004         9.7
# 446  2020-04-02    42     20  0.3  0.019  0.035  0.002         9.3
# 447  2020-04-01    58     26  0.4  0.019  0.040  0.003        10.6
#
#      PRECIPITATION  WIND SPEED  RELATIVE HUMIDITY
# 0              0.0         1.7               32.0
# 1              0.0         1.7               32.0
# 2              0.0         1.7               32.0
# 3              0.0         1.1               39.0
# 4              2.6         0.8               75.0
# ..             ...         ...                ...
# 443            0.0         1.7               29.8
# 444            0.0         2.5               43.4
# 445            0.0         1.6               43.0
# 446            0.0         1.5               44.9
# 447            0.0         1.8               38.5
#
# [448 rows x 11 columns]

# %%
import pandas as pd
import os
openpath = 'C:/Users/ad/Documents/카카오톡 받은 파일/fin/'
file_list = os.listdir(openpath)
name_list = []
for file_name in file_list:
    if ".xlsx" in file_name:
        openfilename = openpath + file_name  
        name_list.append(openfilename)
    
name_list
# Out:
# ['C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_NAMFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/DAEJEONFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/DEAGUFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/INCHEONFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_BUKFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_NAMFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/JE_JUFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/KANGONEFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/KWANG_JUFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYEONG_GIFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_BUKFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_NAMFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/PUSANFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEJONGFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEOULFIN.xlsx',
#  'C:/Users/ad/Documents/카카오톡 받은 파일/fin/ULSANFIN.xlsx']

# %%
for i in name_list:
    print (i)
# Out:
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_NAMFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DAEJEONFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DEAGUFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/INCHEONFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_BUKFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_NAMFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JE_JUFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KANGONEFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KWANG_JUFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYEONG_GIFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_BUKFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_NAMFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/PUSANFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEJONGFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEOULFIN.xlsx
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/ULSANFIN.xlsx

# %%
for i in name_list:
    print(i)
    x = i.split('/')
    filename = x[-1].replace('.xlsx', '')
    print(filename)
# Out:
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx
# CHUNG_BUKFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_NAMFIN.xlsx
# CHUNG_NAMFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DAEJEONFIN.xlsx
# DAEJEONFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DEAGUFIN.xlsx
# DEAGUFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/INCHEONFIN.xlsx
# INCHEONFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_BUKFIN.xlsx
# JEON_BUKFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_NAMFIN.xlsx
# JEON_NAMFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JE_JUFIN.xlsx
# JE_JUFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KANGONEFIN.xlsx
# KANGONEFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KWANG_JUFIN.xlsx
# KWANG_JUFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYEONG_GIFIN.xlsx
# KYEONG_GIFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_BUKFIN.xlsx
# KYUNG_BUKFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_NAMFIN.xlsx
# KYUNG_NAMFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/PUSANFIN.xlsx
# PUSANFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEJONGFIN.xlsx
# SEJONGFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEOULFIN.xlsx
# SEOULFIN
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/ULSANFIN.xlsx
# ULSANFIN

# %%
excel_df = pd.read_excel(openfilename)

# %%
import pandas as pd
import os
openpath = 'C:/Users/ad/Documents/카카오톡 받은 파일/fin/'
file_list = os.listdir(openpath)
name_list = []
for file_name in file_list:
    if ".xlsx" in file_name:
        openfilename = openpath + file_name  
        excel_df = pd.read_excel(openfilename)
        print(openfilename)
        for i in openfilename:
            x = i.split('/')
            filename = x[-1].replace('.xlsx', '')
            #print(filename)
            globals()[f'{filename}FINAL'] = excel_df
            #print(f'{filename}FINAL')
# Out:
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_BUKFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# C
# CFINAL
# H
# HFINAL
# U
# UFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# B
# BFINAL
# U
# UFINAL
# K
# KFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/CHUNG_NAMFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# C
# CFINAL
# H
# HFINAL
# U
# UFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# N
# NFINAL
# A
# AFINAL
# M
# MFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DAEJEONFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# D
# DFINAL
# A
# AFINAL
# E
# EFINAL
# J
# JFINAL
# E
# EFINAL
# O
# OFINAL
# N
# NFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/DEAGUFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# D
# DFINAL
# E
# EFINAL
# A
# AFINAL
# G
# GFINAL
# U
# UFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/INCHEONFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# I
# IFINAL
# N
# NFINAL
# C
# CFINAL
# H
# HFINAL
# E
# EFINAL
# O
# OFINAL
# N
# NFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_BUKFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# J
# JFINAL
# E
# EFINAL
# O
# OFINAL
# N
# NFINAL
# _
# _FINAL
# B
# BFINAL
# U
# UFINAL
# K
# KFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JEON_NAMFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# J
# JFINAL
# E
# EFINAL
# O
# OFINAL
# N
# NFINAL
# _
# _FINAL
# N
# NFINAL
# A
# AFINAL
# M
# MFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/JE_JUFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# J
# JFINAL
# E
# EFINAL
# _
# _FINAL
# J
# JFINAL
# U
# UFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KANGONEFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# K
# KFINAL
# A
# AFINAL
# N
# NFINAL
# G
# GFINAL
# O
# OFINAL
# N
# NFINAL
# E
# EFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KWANG_JUFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# K
# KFINAL
# W
# WFINAL
# A
# AFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# J
# JFINAL
# U
# UFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYEONG_GIFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# K
# KFINAL
# Y
# YFINAL
# E
# EFINAL
# O
# OFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# G
# GFINAL
# I
# IFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_BUKFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# K
# KFINAL
# Y
# YFINAL
# U
# UFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# B
# BFINAL
# U
# UFINAL
# K
# KFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/KYUNG_NAMFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# K
# KFINAL
# Y
# YFINAL
# U
# UFINAL
# N
# NFINAL
# G
# GFINAL
# _
# _FINAL
# N
# NFINAL
# A
# AFINAL
# M
# MFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/PUSANFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# P
# PFINAL
# U
# UFINAL
# S
# SFINAL
# A
# AFINAL
# N
# NFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEJONGFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# S
# SFINAL
# E
# EFINAL
# J
# JFINAL
# O
# OFINAL
# N
# NFINAL
# G
# GFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/SEOULFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# S
# SFINAL
# E
# EFINAL
# O
# OFINAL
# U
# UFINAL
# L
# LFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL
# C:/Users/ad/Documents/카카오톡 받은 파일/fin/ULSANFIN.xlsx
# C
# CFINAL
# :
# :FINAL
#
# FINAL
# U
# UFINAL
# s
# sFINAL
# e
# eFINAL
# r
# rFINAL
# s
# sFINAL
#
# FINAL
# a
# aFINAL
# d
# dFINAL
#
# FINAL
# D
# DFINAL
# o
# oFINAL
# c
# cFINAL
# u
# uFINAL
# m
# mFINAL
# e
# eFINAL
# n
# nFINAL
# t
# tFINAL
# s
# sFINAL
#
# FINAL
# 카
# 카FINAL
# 카
# 카FINAL
# 오
# 오FINAL
# 톡
# 톡FINAL
#
#  FINAL
# 받
# 받FINAL
# 은
# 은FINAL
#
#  FINAL
# 파
# 파FINAL
# 일
# 일FINAL
#
# FINAL
# f
# fFINAL
# i
# iFINAL
# n
# nFINAL
#
# FINAL
# U
# UFINAL
# L
# LFINAL
# S
# SFINAL
# A
# AFINAL
# N
# NFINAL
# F
# FFINAL
# I
# IFINAL
# N
# NFINAL
# .
# .FINAL
# x
# xFINAL
# l
# lFINAL
# s
# sFINAL
# x
# xFINAL

# %%
print('a')
# Out:
# a

# %%
RENAME_ALL = {
    '서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON',
    '울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK',
    '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}
listvalues=list()
for i,j in RENAME_ALL.items():
    listvalues.append(j)
import pandas as pd
test = pd.DataFrame(index=listvalues,columns=['위도','경도'])
test = test[['위도','경도']].astype('float')
test.index.names=['이름']
test.loc['SEOUL']     = [ 37.59057852325989, 126.9741461697108 ]
test.loc['PUSAN']     = [ 35.16646763080438, 129.02660703271857 ]
test.loc['DEAGU']     = [ 35.81991384028659, 128.5446689181621 ]
test.loc['INCHEON']   = [ 37.449887059861396, 126.70211361857983 ]
test.loc['KWANG_JU']  = [ 35.166368382961416, 126.82977521060587 ]
test.loc['DAEJEON']   = [ 36.333919790187515, 127.39531192170182 ]
test.loc['ULSAN']     = [ 35.56562151744547, 129.2697436746425 ]
test.loc['KYEONG_GI'] = [ 37.39689214652871, 127.49626348873487 ]
test.loc['KANGONE']   = [ 35.481133297445965, 128.30797526353385 ]
test.loc['CHUNG_BUK'] = [ 36.99449992376472, 127.67010320984288 ]
test.loc['CHUNG_NAM'] = [ 36.63527888122404, 126.84859514953921 ]
test.loc['JEON_BUK']  = [ 35.708444280199004, 127.11662005953636 ]
test.loc['JEON_NAM']  = [ 34.88949116972007, 126.99172287794916 ]
test.loc['KYUNG_BUK'] = [ 36.39981068831169, 128.83975128231492 ]
test.loc['KYUNG_NAM'] = [ 35.40505429632169, 128.15416667027876 ]
test.loc['JE_JU']     = [ 33.41802888452141, 126.57348525443793 ]
test.loc['SEJONG']    = [ 36.5594077631663, 127.24823548942054 ]

# %%
test = pd.DataFrame()

# %%
test.to_excel('C:/Users/ad/Desktop/test/fin/ce.xlsx')

# %%
test['경도']
# Out:
# 이름
# SEOUL        126.974146
# PUSAN        129.026607
# DEAGU        128.544669
# INCHEON      126.702114
# KWANG_JU     126.829775
# DAEJEON      127.395312
# ULSAN        129.269744
# KYEONG_GI    127.496263
# KANGONE      128.307975
# CHUNG_BUK    127.670103
# CHUNG_NAM    126.848595
# JEON_BUK     127.116620
# JEON_NAM     126.991723
# KYUNG_BUK    128.839751
# KYUNG_NAM    128.154167
# JE_JU        126.573485
# SEJONG       127.248235
# Name: 경도, dtype: float64

# %%
test['위도']
# Out:
# 이름
# SEOUL        37.590579
# PUSAN        35.166468
# DEAGU        35.819914
# INCHEON      37.449887
# KWANG_JU     35.166368
# DAEJEON      36.333920
# ULSAN        35.565622
# KYEONG_GI    37.396892
# KANGONE      35.481133
# CHUNG_BUK    36.994500
# CHUNG_NAM    36.635279
# JEON_BUK     35.708444
# JEON_NAM     34.889491
# KYUNG_BUK    36.399811
# KYUNG_NAM    35.405054
# JE_JU        33.418029
# SEJONG       36.559408
# Name: 위도, dtype: float64

# %%
test['경도']
# Out:
# 이름
# SEOUL        126.974146
# PUSAN        129.026607
# DEAGU        128.544669
# INCHEON      126.702114
# KWANG_JU     126.829775
# DAEJEON      127.395312
# ULSAN        129.269744
# KYEONG_GI    127.496263
# KANGONE      128.307975
# CHUNG_BUK    127.670103
# CHUNG_NAM    126.848595
# JEON_BUK     127.116620
# JEON_NAM     126.991723
# KYUNG_BUK    128.839751
# KYUNG_NAM    128.154167
# JE_JU        126.573485
# SEJONG       127.248235
# Name: 경도, dtype: float64

# %%
RENAME_ALL = {
    '서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON',
    '울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK',
    '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}
listvalues=list()
for i,j in RENAME_ALL.items():
    listvalues.append(j)
import pandas as pd
test = pd.DataFrame(index=listvalues,columns=['위도','경도'])
test = test[['위도','경도']].astype('float')
test.index.names=['이름']
test.loc['SEOUL']     = [ 37.59057852325989, 126.9741461697108 ]
test.loc['PUSAN']     = [ 35.16646763080438, 129.02660703271857 ]
test.loc['DEAGU']     = [ 35.81991384028659, 128.5446689181621 ]
test.loc['INCHEON']   = [ 37.449887059861396, 126.70211361857983 ]
test.loc['KWANG_JU']  = [ 35.166368382961416, 126.82977521060587 ]
test.loc['DAEJEON']   = [ 36.333919790187515, 127.39531192170182 ]
test.loc['ULSAN']     = [ 35.56562151744547, 129.2697436746425 ]
test.loc['KYEONG_GI'] = [ 37.39689214652871, 127.49626348873487 ]
test.loc['KANGONE']   = [ 35.481133297445965, 128.30797526353385 ]
test.loc['CHUNG_BUK'] = [ 36.99449992376472, 127.67010320984288 ]
test.loc['CHUNG_NAM'] = [ 36.63527888122404, 126.84859514953921 ]
test.loc['JEON_BUK']  = [ 35.708444280199004, 127.11662005953636 ]
test.loc['JEON_NAM']  = [ 34.88949116972007, 126.99172287794916 ]
test.loc['KYUNG_BUK'] = [ 36.39981068831169, 128.83975128231492 ]
test.loc['KYUNG_NAM'] = [ 35.40505429632169, 128.15416667027876 ]
test.loc['JE_JU']     = [ 33.41802888452141, 126.57348525443793 ]
test.loc['SEJONG']    = [ 36.5594077631663, 127.24823548942054 ]
save_PATH = 'C:/Users/ad/Desktop/test/fin/위도경도'
test.to_excel(save_PATH + '.xlsx', index=False)
test.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')

# %%
filepath = 'C:/Users/ad/Documents/카카오톡 받은 파일/dd.xlsx'
excel_df = pd.read_excel(filepath)
#------------------------ 함수돌린 결과물 데이터프레임 == excel_df 가정
a = excel_df[['ds', 'yhat']]
# Out:
#      Unnamed: 0         ds      trend  yhat_lower  yhat_upper  trend_lower  \
# 0             0 2020-04-01  62.992761   -3.308848   80.451514    62.992761
# 1             1 2020-04-02  62.894512   -0.664442   77.868116    62.894512
# 2             2 2020-04-03  62.796263    0.457610   86.160430    62.796263
# 3             3 2020-04-04  62.698015   -0.379064   83.858020    62.698015
# 4             4 2020-04-05  62.599766  -10.062579   74.452201    62.599766
# ..          ...        ...        ...         ...         ...          ...
# 453         453 2021-06-28  77.185336   10.527088   92.588871    77.180812
# 454         454 2021-06-29  77.230927   11.083553   92.301393    77.220511
# 455         455 2021-06-30  77.276519   12.850781   93.754360    77.261034
# 456         456 2021-07-01  77.322110   14.707917   96.291117    77.297805
# 457         457 2021-07-02  77.367702   19.962024   98.323832    77.336179
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      62.992761      -23.530599            -23.530599            -23.530599
# 1      62.894512      -22.855834            -22.855834            -22.855834
# 2      62.796263      -20.364074            -20.364074            -20.364074
# 3      62.698015      -20.959097            -20.959097            -20.959097
# 4      62.599766      -30.390758            -30.390758            -30.390758
# ..           ...             ...                   ...                   ...
# 453    77.192271      -23.359703            -23.359703            -23.359703
# 454    77.242575      -25.993250            -25.993250            -25.993250
# 455    77.296383      -23.530599            -23.530599            -23.530599
# 456    77.349563      -22.855834            -22.855834            -22.855834
# 457    77.403035      -20.364074            -20.364074            -20.364074
#
#          daily  daily_lower  daily_upper    weekly  weekly_lower  \
# 0   -23.921902   -23.921902   -23.921902  0.391303      0.391303
# 1   -23.921902   -23.921902   -23.921902  1.066068      1.066068
# 2   -23.921902   -23.921902   -23.921902  3.557828      3.557828
# 3   -23.921902   -23.921902   -23.921902  2.962805      2.962805
# 4   -23.921902   -23.921902   -23.921902 -6.468856     -6.468856
# ..         ...          ...          ...       ...           ...
# 453 -23.921902   -23.921902   -23.921902  0.562199      0.562199
# 454 -23.921902   -23.921902   -23.921902 -2.071348     -2.071348
# 455 -23.921902   -23.921902   -23.921902  0.391303      0.391303
# 456 -23.921902   -23.921902   -23.921902  1.066068      1.066068
# 457 -23.921902   -23.921902   -23.921902  3.557828      3.557828
#
#      weekly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        0.391303                     0                           0
# 1        1.066068                     0                           0
# 2        3.557828                     0                           0
# 3        2.962805                     0                           0
# 4       -6.468856                     0                           0
# ..            ...                   ...                         ...
# 453      0.562199                     0                           0
# 454     -2.071348                     0                           0
# 455      0.391303                     0                           0
# 456      1.066068                     0                           0
# 457      3.557828                     0                           0
#
#      multiplicative_terms_upper       yhat
# 0                             0  39.462163
# 1                             0  40.038679
# 2                             0  42.432190
# 3                             0  41.738918
# 4                             0  32.209008
# ..                          ...        ...
# 453                           0  53.825633
# 454                           0  51.237678
# 455                           0  53.745920
# 456                           0  54.466277
# 457                           0  57.003628
#
# [458 rows x 20 columns]

# %%
a = excel_df['ds']
b = excel_df[['ds', 'yhat']]

# %%
b
# Out:
#             ds       yhat
# 0   2020-04-01  39.462163
# 1   2020-04-02  40.038679
# 2   2020-04-03  42.432190
# 3   2020-04-04  41.738918
# 4   2020-04-05  32.209008
# ..         ...        ...
# 453 2021-06-28  53.825633
# 454 2021-06-29  51.237678
# 455 2021-06-30  53.745920
# 456 2021-07-01  54.466277
# 457 2021-07-02  57.003628
#
# [458 rows x 2 columns]

# %%
for i in test.index :
    lat =
# Out:
# Index(['SEOUL', 'PUSAN', 'DEAGU', 'INCHEON', 'KWANG_JU', 'DAEJEON', 'ULSAN',
#        'KYEONG_GI', 'KANGONE', 'CHUNG_BUK', 'CHUNG_NAM', 'JEON_BUK',
#        'JEON_NAM', 'KYUNG_BUK', 'KYUNG_NAM', 'JE_JU', 'SEJONG'],
#       dtype='object', name='이름')

# %%
test.loc['SEOUL', '위도']
# Out:
# 37.59057852325989

# %%
test
# Out:
#                   위도          경도
# 이름
# SEOUL      37.590579  126.974146
# PUSAN      35.166468  129.026607
# DEAGU      35.819914  128.544669
# INCHEON    37.449887  126.702114
# KWANG_JU   35.166368  126.829775
# DAEJEON    36.333920  127.395312
# ULSAN      35.565622  129.269744
# KYEONG_GI  37.396892  127.496263
# KANGONE    35.481133  128.307975
# CHUNG_BUK  36.994500  127.670103
# CHUNG_NAM  36.635279  126.848595
# JEON_BUK   35.708444  127.116620
# JEON_NAM   34.889491  126.991723
# KYUNG_BUK  36.399811  128.839751
# KYUNG_NAM  35.405054  128.154167
# JE_JU      33.418029  126.573485
# SEJONG     36.559408  127.248235

# %%
# 그래프 웹 시각화
import pandas as pd 
import numpy as np
from bokeh.io import output_notebook, show # bokeh 패키지의 io == input output 기능 /show 역시 보여주는 기능
from bokeh.plotting import figure # bokeh 패키지의 직접 그려주는 기능 / figure이 그림을 그려줌

# %%
output_notebook() # 쥬피터 노트북에서 바로바로 보여줄수 있게 하는 기능
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# 스캐터 relation ( 관계를 규명하는 그래프)
p = figure(plot_width=800, plot_height=400) #width = 너비, height = 높이
# 빈그래프 만들엇음`

# %%
show(p)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1525', ...)
#   <div class="bk-root" id="9b378b6f-f749-4bd8-a5c9-216177f893db" data-root-id="1525"></div>

# %%
x = [ 0, 1, 2, 3, 4, 5 ]
y = [ 0, 1, 2, 3, 4, 5 ]
p.circle(x, y, size=10)
#p.line
# Out:
# GlyphRenderer(id='1646', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="9d9adc64-d4bb-4a82-aaea-4b466c60a864" data-root-id="1525"></div>

# %%
p.circle(x, y, size=100, line_color='orange', fill_color='navy', fill_alpha=0, line_width=10)
show(p)
# Out:
#   <div class="bk-root" id="a1fbbe2b-d235-4da4-9767-9a9395fe9ab1" data-root-id="1525"></div>
