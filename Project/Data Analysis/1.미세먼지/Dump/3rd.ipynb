# %%
import pandas as pd
import datetime
#!pip install xlrd
#!pip install pandas
#!pip install openyxl

# %%
# 엑셀 경로 받아오는 함수(pm2.5)
def excelappend(yy, mm):
    # 엑셀경로
    filepath = 'C:/Users/minipojectweb/data/pm25/{}{}.xls'.format(yy, mm)
    # 엑셀불러오기"
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)


def test111(): 
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    PH25DF      = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(str(yy), str(mm).zfill(2))
                PH25DF = PH25DF.append(temp, ignore_index=True)
                print(f'{yy}{str(mm).zfill(2)} success')

# %%
test111()
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
# 엑셀 경로 받아오는 함수(pm2.5)
def excelappend(yy, mm, zz='pm25'):
    
    # 엑셀경로
    filepath = 'C:/Users/minipojectweb/data/{}/{}{}.xls'.format(zz, yy, mm)
    # 엑셀불러오기"
    excel_df = pd.read_excel(filepath, header=3)
    print(filepath)
    return(excel_df)

# %%
def testMoudle():

    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    PH25DF      = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(str(yy), str(mm).zfill(2))
                PH25DF = PH25DF.append(temp, ignore_index=True)
                print(f'{yy}{str(mm).zfill(2)} success')

# %%
# 엑셀 경로 받아오는 함수(pm2.5)
def excelappend(yy, mm, aa='pm25'):
    
    # 엑셀경로
    filepath = f'C:/Users/minipojectweb/data/{aa}/{yy}{mm}.xls'
    # 엑셀불러오기"
    excel_df = pd.read_excel(filepath, header=3)
    print(filepath)
    return(excel_df)

# %%
mmm = '04'
aaa = 'pm10'
excelappend(2020, str(mmm).zfill(2), aaa).head(1)
# Out:
# C:/Users/minipojectweb/data/pm10/202004.xls
#            날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  경북  경남  제주  \
# 0  2020-04-30  34  31  41  31  37  35  39  40  39  39  35  35  30  40  31  36
#
#    세종
# 0  39

# %%
def testMoudle(path='pm25'):
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    PH25DF      = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(str(yy), str(mm).zfill(2), path)
                PH25DF = PH25DF.append(temp, ignore_index=True)
                PH25DF
                print(f'{yy}{str(mm).zfill(2)} success')

# %%
PH25DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %%
# 엑셀 경로 받아오는 함수(pm10)
def excelappendph10(yy, mm):
    
    # 엑셀경로
    filepath = 'C:/Users/minipojectweb/data/pm10/{}{}.xls'.format(yy, mm)
    # 엑셀불러오기"
    excel_df = pd.read_excel(filepath, header=3)

    return(excel_df)


# 데이터프레임 만드는 반복문 (pm10)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
PH10DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendph10(str(yy), str(mm).zfill(2))
            PH10DF = PH10DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')


# 경로에 저장  
PH10DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_PH10' # 저장경로
PH10DF.to_excel(save_PATH + '.xlsx', index=False)
PH10DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
PH10DF
# Out:
#              날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  경북  경남  \
# 426  2021-06-20  50  42  36  61  35  34  43  56  34  38  46  39  34  35  36
# 427  2021-06-19  42  39  31  44  28  28  33  47  26  38  37  33  27  28  31
# 428  2021-06-18  17  23  31  15  13  12  27  19  15  13  13  14  15  22  24
# 429  2021-06-17  17  15  20  18  17  13  12  19  15  14  15  17  14  19  15
# 430  2021-06-16  10  10  11  13  10   9  10  13  10  11  16  13  11  14  10
# ..          ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 25   2020-04-05  47  34  33  44  32  35  31  48  33  41  45  36  31  31  32
# 26   2020-04-04  68  48  57  60  69  68  47  77  59  77  82  73  61  59  50
# 27   2020-04-03  56  37  43  47  47  44  40  56  40  47  54  52  40  39  33
# 28   2020-04-02  39  30  38  36  41  38  29  40  31  37  43  42  39  33  31
# 29   2020-04-01  69  35  56  60  43  50  41  74  49  66  61  49  40  49  41
#
#        제주  세종
# 426  37.0  38
# 427  25.0  29
# 428  17.0  12
# 429  19.0  13
# 430  15.0  11
# ..    ...  ..
# 25   36.0  39
# 26   68.0  74
# 27   48.0  50
# 28   56.0  42
# 29   44.0  58
#
# [446 rows x 18 columns]

# %%
aa = {'서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON','울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK', '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}
PH10DF_I = PH10DF.rename(aa, axis='columns')

# %%
PH10DF_I
# Out:
#              날짜  SEOUL  PUSAN  DEAGU  INCHEON  KWANG_JU  DAEJEON  ULSAN  \
# 426  2021-06-20     50     42     36       61        35       34     43
# 427  2021-06-19     42     39     31       44        28       28     33
# 428  2021-06-18     17     23     31       15        13       12     27
# 429  2021-06-17     17     15     20       18        17       13     12
# 430  2021-06-16     10     10     11       13        10        9     10
# ..          ...    ...    ...    ...      ...       ...      ...    ...
# 25   2020-04-05     47     34     33       44        32       35     31
# 26   2020-04-04     68     48     57       60        69       68     47
# 27   2020-04-03     56     37     43       47        47       44     40
# 28   2020-04-02     39     30     38       36        41       38     29
# 29   2020-04-01     69     35     56       60        43       50     41
#
#      KYEONG_GI  KANGONE  CHUNG_BUK  CHUNG_NAM  JEON_BUK  JEON_NAM  KYUNG_BUK  \
# 426         56       34         38         46        39        34         35
# 427         47       26         38         37        33        27         28
# 428         19       15         13         13        14        15         22
# 429         19       15         14         15        17        14         19
# 430         13       10         11         16        13        11         14
# ..         ...      ...        ...        ...       ...       ...        ...
# 25          48       33         41         45        36        31         31
# 26          77       59         77         82        73        61         59
# 27          56       40         47         54        52        40         39
# 28          40       31         37         43        42        39         33
# 29          74       49         66         61        49        40         49
#
#      KYUNG_NAM  JE_JU  SEJONG
# 426         36   37.0      38
# 427         31   25.0      29
# 428         24   17.0      12
# 429         15   19.0      13
# 430         10   15.0      11
# ..         ...    ...     ...
# 25          32   36.0      39
# 26          50   68.0      74
# 27          33   48.0      50
# 28          31   56.0      42
# 29          41   44.0      58
#
# [446 rows x 18 columns]

# %%
import pandas as pd
import datetime
RENAME_ALL = {
    '서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON',
    '울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK',
    '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}


# pm2.5-----------------------------------------------------------------------------
def excelappend(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/pm25/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
PH25DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappend(str(yy), str(mm).zfill(2))
            PH25DF = PH25DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
PH25DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_PH2_5' # 저장경로
PH25DF.to_excel(save_PATH + '.xlsx', index=False)
PH25DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
PH25DF_I = PH25DF.rename(RENAME_ALL, axis='columns')

# pm10-----------------------------------------------------------------------------
def excelappendph10(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/pm10/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
PH10DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendph10(str(yy), str(mm).zfill(2))
            PH10DF = PH10DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
PH10DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_PH10' # 저장경로
PH10DF.to_excel(save_PATH + '.xlsx', index=False)
PH10DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
PH10DF_I = PH10DF.rename(RENAME_ALL, axis='columns')

# o3오존-----------------------------------------------------------------------------
def excelappendpho3(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/o3/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
O3DF        = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendpho3(str(yy), str(mm).zfill(2))
            O3DF = O3DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
O3DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_O3' # 저장경로
O3DF.to_excel(save_PATH + '.xlsx', index=False)
O3DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
O3DF_I = O3DF.rename(RENAME_ALL, axis='columns')

# so2아황산가스-----------------------------------------------------------------------------
def excelappendso2(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/so2/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
SO2DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendso2(str(yy), str(mm).zfill(2))
            SO2DF = SO2DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
SO2DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_SO2' # 저장경로
SO2DF.to_excel(save_PATH + '.xlsx', index=False)
SO2DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
SO2DF_I = SO2DF.rename(RENAME_ALL, axis='columns')

#일산화탄소co---------------------
def excelappendCO(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/co/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
CODF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendCO(str(yy), str(mm).zfill(2))
            CODF = CODF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
CODF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_CO' # 저장경로
CODF.to_excel(save_PATH + '.xlsx', index=False)
CODF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
CODF_I = CODF.rename(RENAME_ALL, axis='columns')

#일산화질소NO2---------------------
def excelappendNO2(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/no2/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
NO2DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendNO2(str(yy), str(mm).zfill(2))
            NO2DF = NO2DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
NO2DF.sort_values( by = '날짜', ascending=False, inplace=True)
save_PATH = 'C:/Users/ad/Desktop/test/KOR_NO2' # 저장경로
NO2DF.to_excel(save_PATH + '.xlsx', index=False)
NO2DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
NO2DF_I = NO2DF.rename(RENAME_ALL, axis='columns')
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
NO2DF
# Out:
#              날짜     서울     부산     대구     인천     광주     대전     울산     경기  \
# 427  2021-06-20  0.014  0.015  0.009  0.010  0.007  0.007  0.017  0.010
# 426  2021-06-20  0.014  0.015  0.009  0.010  0.007  0.007  0.017  0.010
# 428  2021-06-19  0.016  0.013  0.009  0.012  0.007  0.009  0.014  0.012
# 429  2021-06-18  0.015  0.018  0.013  0.011  0.008  0.009  0.022  0.011
# 430  2021-06-17  0.016  0.011  0.008  0.016  0.011  0.009  0.012  0.012
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25   2020-04-05  0.015  0.010  0.009  0.011  0.009  0.012  0.011  0.011
# 26   2020-04-04  0.015  0.014  0.015  0.012  0.015  0.012  0.016  0.014
# 27   2020-04-03  0.028  0.022  0.019  0.022  0.019  0.020  0.024  0.022
# 28   2020-04-02  0.027  0.015  0.017  0.023  0.015  0.019  0.017  0.021
# 29   2020-04-01  0.020  0.020  0.020  0.016  0.013  0.019  0.019  0.020
#
#         강원     충북     충남     전북     전남     경북     경남     제주     세종
# 427  0.006  0.008  0.006  0.006  0.008  0.008  0.010  0.008  0.007
# 426  0.006  0.008  0.006  0.006  0.008  0.008  0.010  0.008  0.007
# 428  0.006  0.009  0.007  0.006  0.006  0.007  0.009  0.006  0.008
# 429  0.007  0.008  0.006  0.007  0.006  0.009  0.013  0.008  0.008
# 430  0.006  0.010  0.008  0.008  0.007  0.007  0.009  0.005  0.009
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25   0.009  0.011  0.009  0.008  0.007  0.008  0.009  0.006  0.010
# 26   0.010  0.014  0.010  0.010  0.009  0.010  0.013  0.009  0.013
# 27   0.011  0.017  0.015  0.014  0.011  0.013  0.017  0.010  0.019
# 28   0.010  0.015  0.014  0.013  0.010  0.012  0.014  0.010  0.019
# 29   0.013  0.019  0.014  0.011  0.009  0.014  0.016  0.007  0.019
#
# [447 rows x 18 columns]

# %%
for city in PH10DF_I.columns[1:]:
    globals()[f'{city}_df0'] = PH10DF_I[ [ '날짜',city ] ].rename({ city:'PH10'}, axis='columns')
    # print(city)
    # print(globals()[f'{city}_df0'])

for city in PH25DF_I.columns[1:]:
    globals()[f'{city}_df1'] = PH25DF_I[ [ '날짜',city ] ].rename({ city:'PH2.5'}, axis='columns')
    globals()[f'{city}_df1'] = pd.merge(left = globals()[f'{city}_df0'], right = globals()[f'{city}_df1'], how = 'left', left_on ='날짜', right_on='날짜')
    # print(city)
    # print(globals()[f'{city}_df1'])

for city in O3DF_I.columns[1:]:
    globals()[f'{city}_df2'] = O3DF_I[ [ '날짜',city ] ].rename({ city:'O3'}, axis='columns')
    globals()[f'{city}_df2'] = pd.merge(left = globals()[f'{city}_df1'], right = globals()[f'{city}_df2'], how = 'left', left_on ='날짜', right_on='날짜')
    # print(city)
    # print(globals()[f'{city}_df2'])

for city in NO2DF_I.columns[1:]:
    globals()[f'{city}_df3'] = NO2DF_I[ [ '날짜',city ] ].rename({ city:'NO2'}, axis='columns')
    globals()[f'{city}_df3'] = pd.merge(left = globals()[f'{city}_df2'], right = globals()[f'{city}_df3'], how = 'left', left_on ='날짜', right_on='날짜')
    # print(city)
    # print(globals()[f'{city}_df3'])

for city in CODF_I.columns[1:]:
    globals()[f'{city}_df4'] = CODF_I[ [ '날짜',city ] ].rename({ city:'CO'}, axis='columns')
    globals()[f'{city}_df4'] = pd.merge(left = globals()[f'{city}_df3'], right = globals()[f'{city}_df4'], how = 'left', left_on ='날짜', right_on='날짜')
    # print(city)
    # print(globals()[f'{city}_df4'])

for city in SO2DF_I.columns[1:]:
    globals()[f'{city}_df5'] = SO2DF_I[ [ '날짜',city ] ].rename({ city:'SO2'}, axis='columns')
    globals()[f'{city}_df5'] = pd.merge(left = globals()[f'{city}_df4'], right = globals()[f'{city}_df5'], how = 'left', left_on ='날짜', right_on='날짜')
    print(city)
    print(globals()[f'{city}_df5'])
    globals()[f'{city}_df5'].sort_values( by = '날짜', ascending=False, inplace=True)
    pppath    = f'{city}_df5'
    save_PATH = f'C:/Users/ad/Desktop/test/{pppath}'
    globals()[f'{city}_df5'].to_excel(save_PATH + '.xlsx', index=False)
    globals()[f'{city}_df5'].to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
# Out:
# SEOUL
#              날짜  PH10  PH2.5     O3    NO2   CO    SO2
# 0    2021-06-20    50     28  0.059  0.014  0.5  0.004
# 1    2021-06-20    50     28  0.059  0.014  0.5  0.004
# 2    2021-06-20    50     28  0.059  0.014  0.5  0.004
# 3    2021-06-20    50     28  0.059  0.014  0.5  0.004
# 4    2021-06-20    50     28  0.059  0.014  0.5  0.004
# ..          ...   ...    ...    ...    ...  ...    ...
# 456  2020-04-05    47     22  0.038  0.015  0.4  0.003
# 457  2020-04-04    68     27  0.037  0.015  0.4  0.003
# 458  2020-04-03    56     32  0.032  0.028  0.5  0.003
# 459  2020-04-02    39     24  0.029  0.027  0.5  0.003
# 460  2020-04-01    69     30  0.041  0.020  0.5  0.004
#
# [461 rows x 7 columns]
# PUSAN
#              날짜  PH10  PH2.5     O3    NO2   CO    SO2
# 0    2021-06-20    42     26  0.056  0.015  0.4  0.003
# 1    2021-06-20    42     26  0.056  0.015  0.4  0.003
# 2    2021-06-20    42     26  0.056  0.015  0.4  0.003
# 3    2021-06-20    42     26  0.056  0.015  0.4  0.003
# 4    2021-06-20    42     26  0.056  0.015  0.4  0.003
# ..          ...   ...    ...    ...    ...  ...    ...
# 456  2020-04-05    34     11  0.042  0.010  0.3  0.003
# 457  2020-04-04    48     23  0.047  0.014  0.4  0.004
# 458  2020-04-03    37     21  0.039  0.022  0.4  0.004
# 459  2020-04-02    30     16  0.040  0.015  0.3  0.003
# 460  2020-04-01    35     19  0.036  0.020  0.4  0.003
#
# [461 rows x 7 columns]
# DEAGU
#              날짜  PH10  PH2.5     O3    NO2   CO    SO2
# 0    2021-06-20    36     20  0.056  0.009  0.4  0.002
# 1    2021-06-20    36     20  0.056  0.009  0.4  0.002
# 2    2021-06-20    36     20  0.056  0.009  0.4  0.002
# 3    2021-06-20    36     20  0.056  0.009  0.4  0.002
# 4    2021-06-20    36     20  0.056  0.009  0.4  0.002
# ..          ...   ...    ...    ...    ...  ...    ...
# 456  2020-04-05    33     12  0.038  0.009  0.4  0.003
# 457  2020-04-04    57     25  0.041  0.015  0.4  0.003
# 458  2020-04-03    43     24  0.038  0.019  0.5  0.003
# 459  2020-04-02    38     17  0.035  0.017  0.4  0.003
# 460  2020-04-01    56     30  0.038  0.020  0.5  0.003
#
# [461 rows x 7 columns]
# INCHEON
#              날짜  PH10  PH2.5     O3    NO2   CO    SO2
# 0    2021-06-20
F.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
NO2DF_I = NO2DF.rename(RENAME_ALL, axis='columns')

# %%
for i in SO2DF_I.columns[1:] :
    print(i)
# Out:
# SEOUL
# PUSAN
# DEAGU
# INCHEON
# KWANG_JU
# DAEJEON
# ULSAN
# KYEONG_GI
# KANGONE
# CHUNG_BUK
# CHUNG_NAM
# JEON_BUK
# JEON_NAM
# KYUNG_BUK
# KYUNG_NAM
# JE_JU
# SEJONG

# %%
def excelappendNO2(yy, mm):
    filepath = 'C:/Users/minipojectweb/data/no2/{}{}.xls'.format(yy, mm)
    excel_df = pd.read_excel(filepath, header=3)
    return(excel_df)
CURRENTTIME = datetime.datetime.today()
CURRENTTIME = int(CURRENTTIME.strftime('%m'))
NO2DF      = pd.DataFrame()
for yy in [2020, 2021]:
    for mm in range (1, 13):
        if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
            print(f'{yy}{str(mm).zfill(2)} fail')
        else:    
            temp = excelappendNO2(str(yy), str(mm).zfill(2))
            NO2DF = NO2DF.append(temp, ignore_index=True)
            print(f'{yy}{str(mm).zfill(2)} success')
A = NO2DF.sort_values( by = '날짜', ascending=False)
NO2DF[400:]
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# 202004 success
# 202005 success
# 202006 success
# 202007 success
# 202008 success
# 202009 success
# 202010 success
# 202011 success
# 202012 success
# 202101 success
# 202102 success
# 202103 success
# 202104 success
# 202105 success
# 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
#              날짜     서울     부산     대구     인천     광주     대전     울산     경기  \
# 400  2021-05-26  0.017  0.019  0.017  0.015  0.008  0.018  0.022  0.015
# 401  2021-05-25  0.016  0.016  0.015  0.012  0.009  0.012  0.019  0.013
# 402  2021-05-24  0.017  0.020  0.013  0.014  0.009  0.014  0.026  0.014
# 403  2021-05-23  0.016  0.016  0.009  0.015  0.007  0.012  0.015  0.012
# 404  2021-05-22  0.019  0.013  0.008  0.015  0.008  0.010  0.017  0.013
# 405  2021-05-21  0.017  0.010  0.009  0.011  0.007  0.009  0.014  0.014
# 406  2021-05-20  0.023  0.019  0.015  0.022  0.011  0.017  0.021  0.019
# 407  2021-05-19  0.026  0.018  0.014  0.024  0.009  0.015  0.020  0.020
# 408  2021-05-18  0.025  0.019  0.015  0.020  0.009  0.013  0.018  0.018
# 409  2021-05-17  0.018  0.016  0.012  0.015  0.007  0.009  0.015  0.015
# 410  2021-05-16  0.011  0.009  0.010  0.012  0.004  0.008  0.012  0.009
# 411  2021-05-15  0.022  0.016  0.021  0.021  0.007  0.011  0.025  0.016
# 412  2021-05-14  0.031  0.018  0.017  0.028  0.011  0.020  0.028  0.022
# 413  2021-05-13  0.030  0.016  0.014  0.031  0.012  0.020  0.022  0.024
# 414  2021-05-12  0.019  0.011  0.009  0.021  0.009  0.010  0.013  0.016
# 415  2021-05-11  0.019  0.012  0.013  0.022  0.010  0.010  0.016  0.014
# 416  2021-05-10  0.029  0.017  0.019  0.029  0.010  0.017  0.020  0.022
# 417  2021-05-09  0.012  0.010  0.005  0.010  0.007  0.008  0.011  0.010
# 418  2021-05-08  0.014  0.012  0.011  0.012  0.008  0.008  0.014  0.011
# 419  2021-05-07  0.020  0.016  0.017  0.013  0.011  0.016  0.018  0.015
# 420  2021-05-06  0.024  0.021  0.016  0.020  0.014  0.016  0.024  0.019
# 421  2021-05-05  0.013  0.008  0.005  0.011  0.007  0.007  0.010  0.010
# 12  10  21
# 13  11  50
# 14  17  69
# 15  11  46
# 16  22  43
# 17  15  51
# 18  12  40
# 19  13  24
# 20  10  15
# 21   8   9
# 22  19  21
# 23  21  30
# 24  15  45
# 25  10  26
# 26   9  12
# 27  13   8
# 28  22   9
# 29   9  17

# %%
def test(aa):
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    global PH25DF
    PH25DF      = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(aa, str(yy), str(mm).zfill(2))
                PH25DF = PH25DF.append(temp, ignore_index=True)
                print(f'{aa} {yy}{str(mm).zfill(2)} success')

    PH25DF.sort_values( by = '날짜', ascending=False, inplace=True)
    save_PATH = f'C:/Users/ad/Desktop/test/KOR_{aa}' # 저장경로
    PH25DF.to_excel(save_PATH + '.xlsx', index=False)
    PH25DF.to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
    global PH25DF_I
    PH25DF_I = PH25DF.rename(RENAME_ALL, axis='columns')

# %%
test('pm25')
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm25/202004.xls
# pm25 202004 success
# C:/Users/minipojectweb/data/pm25/202005.xls
# pm25 202005 success
# C:/Users/minipojectweb/data/pm25/202006.xls
# pm25 202006 success
# C:/Users/minipojectweb/data/pm25/202007.xls
# pm25 202007 success
# C:/Users/minipojectweb/data/pm25/202008.xls
# pm25 202008 success
# C:/Users/minipojectweb/data/pm25/202009.xls
# pm25 202009 success
# C:/Users/minipojectweb/data/pm25/202010.xls
# pm25 202010 success
# C:/Users/minipojectweb/data/pm25/202011.xls
# pm25 202011 success
# C:/Users/minipojectweb/data/pm25/202012.xls
# pm25 202012 success
# C:/Users/minipojectweb/data/pm25/202101.xls
# pm25 202101 success
# C:/Users/minipojectweb/data/pm25/202102.xls
# pm25 202102 success
# C:/Users/minipojectweb/data/pm25/202103.xls
# pm25 202103 success
# C:/Users/minipojectweb/data/pm25/202104.xls
# pm25 202104 success
# C:/Users/minipojectweb/data/pm25/202105.xls
# pm25 202105 success
# C:/Users/minipojectweb/data/pm25/202106.xls
# pm25 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
PH25DF = pd.DataFrame()
PH25DF_I = pd.DataFrame()

# %%
PH25DF
# Out:
#              날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  경북  경남  \
# 426  2021-06-21  34  28  22  36  25  39  29  42  34  45  42  42  23  23  21
# 427  2021-06-20  31  26  20  40  22  19  29  34  19  23  27  22  21  20  22
# 428  2021-06-19  26  23  15  29  16  15  20  29  14  23  22  20  15  14  17
# 429  2021-06-18  11  15  19  10   8   5  18  11   7   7   8   8   8  14  16
# 430  2021-06-17   8   9  10  10  10   6   6   9   6   7   7   9   7   8   8
# ..          ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 25   2020-04-05  22  11  12  17  11  14   9  19  15  17  18  13  10  11  10
# 26   2020-04-04  27  23  25  19  24  22  22  27  26  29  26  24  21  23  21
# 27   2020-04-03  32  21  24  24  28  25  24  32  23  30  32  32  22  22  19
# 28   2020-04-02  24  16  17  21  20  21  17  24  21  22  25  22  18  17  14
# 29   2020-04-01  30  19  30  23  21  23  23  30  30  36  26  22  19  25  22
#
#        제주  세종
# 426  14.0  32
# 427  21.0  19
# 428  16.0  14
# 429   9.0   4
# 430   8.0   5
# ..    ...  ..
# 25   12.0  14
# 26   27.0  25
# 27   26.0  28
# 28   24.0  20
# 29   21.0  26
#
# [447 rows x 18 columns]

# %%
def test(aa):
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    globals()[f'{aa}DF'] = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(aa, str(yy), str(mm).zfill(2))
                globals()[f'{aa}DF'] = globals()[f'{aa}DF'].append(temp, ignore_index=True)
                print(f'{aa} {yy}{str(mm).zfill(2)} success')

    globals()[f'{aa}DF'].sort_values( by = '날짜', ascending=False, inplace=True)
    save_PATH = f'C:/Users/ad/Desktop/test/KOR_{aa}' # 저장경로
    globals()[f'{aa}DF'].to_excel(save_PATH + '.xlsx', index=False)
    globals()[f'{aa}DF'].to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
    globals()[f'{aa}DF_I'] = globals()[f'{aa}DF'].rename(RENAME_ALL, axis='columns')

# %%
test('pm25')
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm25/202004.xls
# pm25 202004 success
# C:/Users/minipojectweb/data/pm25/202005.xls
# pm25 202005 success
# C:/Users/minipojectweb/data/pm25/202006.xls
# pm25 202006 success
# C:/Users/minipojectweb/data/pm25/202007.xls
# pm25 202007 success
# C:/Users/minipojectweb/data/pm25/202008.xls
# pm25 202008 success
# C:/Users/minipojectweb/data/pm25/202009.xls
# pm25 202009 success
# C:/Users/minipojectweb/data/pm25/202010.xls
# pm25 202010 success
# C:/Users/minipojectweb/data/pm25/202011.xls
# pm25 202011 success
# C:/Users/minipojectweb/data/pm25/202012.xls
# pm25 202012 success
# C:/Users/minipojectweb/data/pm25/202101.xls
# pm25 202101 success
# C:/Users/minipojectweb/data/pm25/202102.xls
# pm25 202102 success
# C:/Users/minipojectweb/data/pm25/202103.xls
# pm25 202103 success
# C:/Users/minipojectweb/data/pm25/202104.xls
# pm25 202104 success
# C:/Users/minipojectweb/data/pm25/202105.xls
# pm25 202105 success
# C:/Users/minipojectweb/data/pm25/202106.xls
# pm25 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
pm25DF
# Out:
#              날짜  서울  부산  대구  인천  광주  대전  울산  경기  강원  충북  충남  전북  전남  경북  경남  \
# 426  2021-06-21  34  28  22  36  25  39  29  42  34  45  42  42  23  23  21
# 427  2021-06-20  31  26  20  40  22  19  29  34  19  23  27  22  21  20  22
# 428  2021-06-19  26  23  15  29  16  15  20  29  14  23  22  20  15  14  17
# 429  2021-06-18  11  15  19  10   8   5  18  11   7   7   8   8   8  14  16
# 430  2021-06-17   8   9  10  10  10   6   6   9   6   7   7   9   7   8   8
# ..          ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 25   2020-04-05  22  11  12  17  11  14   9  19  15  17  18  13  10  11  10
# 26   2020-04-04  27  23  25  19  24  22  22  27  26  29  26  24  21  23  21
# 27   2020-04-03  32  21  24  24  28  25  24  32  23  30  32  32  22  22  19
# 28   2020-04-02  24  16  17  21  20  21  17  24  21  22  25  22  18  17  14
# 29   2020-04-01  30  19  30  23  21  23  23  30  30  36  26  22  19  25  22
#
#        제주  세종
# 426  14.0  32
# 427  21.0  19
# 428  16.0  14
# 429   9.0   4
# 430   8.0   5
# ..    ...  ..
# 25   12.0  14
# 26   27.0  25
# 27   26.0  28
# 28   24.0  20
# 29   21.0  26
#
# [447 rows x 18 columns]

# %%
import pandas as pd
import datetime
RENAME_ALL = {
    '서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON',
    '울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK',
    '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}

def excelappend(aa, yy, mm):
    filepath = f'C:/Users/minipojectweb/data/{aa}/{yy}{mm}.xls'
    excel_df = pd.read_excel(filepath, header=3)
    print (filepath)
    return(excel_df)

def appendname(aa):
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    globals()[f'{aa}DF'] = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(aa, str(yy), str(mm).zfill(2))
                globals()[f'{aa}DF'] = globals()[f'{aa}DF'].append(temp, ignore_index=True)
                print(f'{aa} {yy}{str(mm).zfill(2)} success')

    globals()[f'{aa}DF'].sort_values( by = '날짜', ascending=False, inplace=True)
    save_PATH = f'C:/Users/ad/Desktop/test/tot/KOR_{aa}' # 저장경로
    globals()[f'{aa}DF'].to_excel(save_PATH + '.xlsx', index=False)
    globals()[f'{aa}DF'].to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
    globals()[f'{aa}DF_I'] = globals()[f'{aa}DF'].rename(RENAME_ALL, axis='columns')

append_list = ['pm10', 'pm25', 'co', 'no2', 'o3', 'so2']

for i in append_list:
    appendname(i)
    print(i)
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm10/202004.xls
# pm10 202004 success
# C:/Users/minipojectweb/data/pm10/202005.xls
# pm10 202005 success
# C:/Users/minipojectweb/data/pm10/202006.xls
# pm10 202006 success
# C:/Users/minipojectweb/data/pm10/202007.xls
# pm10 202007 success
# C:/Users/minipojectweb/data/pm10/202008.xls
# pm10 202008 success
# C:/Users/minipojectweb/data/pm10/202009.xls
# pm10 202009 success
# C:/Users/minipojectweb/data/pm10/202010.xls
# pm10 202010 success
# C:/Users/minipojectweb/data/pm10/202011.xls
# pm10 202011 success
# C:/Users/minipojectweb/data/pm10/202012.xls
# pm10 202012 success
# C:/Users/minipojectweb/data/pm10/202101.xls
# pm10 202101 success
# C:/Users/minipojectweb/data/pm10/202102.xls
# pm10 202102 success
# C:/Users/minipojectweb/data/pm10/202103.xls
# pm10 202103 success
# C:/Users/minipojectweb/data/pm10/202104.xls
# pm10 202104 success
# C:/Users/minipojectweb/data/pm10/202105.xls
# pm10 202105 success
# C:/Users/minipojectweb/data/pm10/202106.xls
# pm10 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/o3/202004.xls
# o3 202004 success
# C:/Users/minipojectweb/data/o3/202005.xls
# o3 202005 success
# C:/Users/minipojectweb/data/o3/202006.xls
# o3 202006 success
# C:/Users/minipojectweb/data/o3/202007.xls
# o3 202007 success
# C:/Users/minipojectweb/data/o3/202008.xls
# o3 202008 success
# C:/Users/minipojectweb/data/o3/202009.xls
# o3 202009 success
# C:/Users/minipojectweb/data/o3/202010.xls
# o3 202010 success
# C:/Users/minipojectweb/data/o3/202011.xls
# o3 202011 success
# C:/Users/minipojectweb/data/o3/202012.xls
# o3 202012 success
# C:/Users/minipojectweb/data/o3/202101.xls
# o3 202101 success
# C:/Users/minipojectweb/data/o3/202102.xls
# o3 202102 success
# C:/Users/minipojectweb/data/o3/202103.xls
# o3 202103 success
# C:/Users/minipojectweb/data/o3/202104.xls
# o3 202104 success
# C:/Users/minipojectweb/data/o3/202105.xls
# o3 202105 success
# C:/Users/minipojectweb/data/o3/202106.xls
# o3 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# o3
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/so2/202004.xls
# so2 202004 success
# C:/Users/minipojectweb/data/so2/202005.xls
# so2 202005 success
# C:/Users/minipojectweb/data/so2/202006.xls
# so2 202006 success
# C:/Users/minipojectweb/data/so2/202007.xls
# so2 202007 success
# C:/Users/minipojectweb/data/so2/202008.xls
# so2 202008 success
# C:/Users/minipojectweb/data/so2/202009.xls
# so2 202009 success
# C:/Users/minipojectweb/data/so2/202010.xls
# so2 202010 success
# C:/Users/minipojectweb/data/so2/202011.xls
# so2 202011 success
# C:/Users/minipojectweb/data/so2/202012.xls
# so2 202012 success
# C:/Users/minipojectweb/data/so2/202101.xls
# so2 202101 success
# C:/Users/minipojectweb/data/so2/202102.xls
# so2 202102 success
# C:/Users/minipojectweb/data/so2/202103.xls
# so2 202103 success
# C:/Users/minipojectweb/data/so2/202104.xls
# so2 202104 success
# C:/Users/minipojectweb/data/so2/202105.xls
# so2 202105 success
# C:/Users/minipojectweb/data/so2/202106.xls
# so2 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# so2

# %%
o3DF_I
# Out:
#              날짜  SEOUL  PUSAN  DEAGU  INCHEON  KWANG_JU  DAEJEON  ULSAN  \
# 426  2021-06-21  0.053  0.030  0.040    0.055     0.037    0.067  0.029
# 427  2021-06-20  0.059  0.056  0.056    0.065     0.051    0.057  0.059
# 428  2021-06-19  0.060  0.054  0.045    0.060     0.051    0.048  0.052
# 429  2021-06-18  0.031  0.024  0.024    0.040     0.031    0.030  0.024
# 430  2021-06-17  0.029  0.030  0.031    0.029     0.029    0.033  0.029
# ..          ...    ...    ...    ...      ...       ...      ...    ...
# 25   2020-04-05  0.038  0.042  0.038    0.043     0.041    0.034  0.042
# 26   2020-04-04  0.037  0.047  0.041    0.043     0.039    0.041  0.044
# 27   2020-04-03  0.032  0.039  0.038    0.040     0.042    0.035  0.040
# 28   2020-04-02  0.029  0.040  0.035    0.034     0.039    0.030  0.040
# 29   2020-04-01  0.041  0.036  0.038    0.047     0.042    0.034  0.034
#
#      KYEONG_GI  KANGONE  CHUNG_BUK  CHUNG_NAM  JEON_BUK  JEON_NAM  KYUNG_BUK  \
# 426      0.057    0.048      0.063      0.071     0.057     0.038      0.046
# 427      0.061    0.054      0.055      0.068     0.054     0.048      0.050
# 428      0.060    0.042      0.050      0.055     0.048     0.047      0.044
# 429      0.034    0.027      0.025      0.039     0.033     0.028      0.027
# 430      0.031    0.024      0.028      0.036     0.030     0.035      0.030
# ..         ...      ...        ...        ...       ...       ...        ...
# 25       0.040    0.038      0.037      0.041     0.038     0.040      0.041
# 26       0.039    0.046      0.041      0.041     0.041     0.046      0.049
# 27       0.036    0.046      0.040      0.038     0.040     0.045      0.047
# 28       0.033    0.039      0.037      0.035     0.036     0.041      0.041
# 29       0.042    0.039      0.038      0.039     0.040     0.045      0.041
#
#      KYUNG_NAM  JE_JU  SEJONG
# 426      0.031  0.044   0.073
# 427      0.058  0.057   0.064
# 428      0.050  0.043   0.050
# 429      0.029  0.032   0.031
# 430      0.034  0.041   0.034
# ..         ...    ...     ...
# 25       0.044  0.048   0.042
# 26       0.051  0.056   0.043
# 27       0.043  0.053   0.042
# 28       0.042  0.049   0.035
# 29       0.043  0.053   0.040
#
# [447 rows x 18 columns]

# %%
import pandas as pd
import datetime


def excelappend(aa, yy, mm):
    filepath = f'C:/Users/minipojectweb/data/{aa}/{yy}{mm}.xls'
    excel_df = pd.read_excel(filepath, header=3)
    print (filepath)
    return(excel_df)

def appendname(aa):
    RENAME_ALL = {
    '서울':'SEOUL', '부산':'PUSAN', '대구':'DEAGU', '인천':'INCHEON', '광주':'KWANG_JU', '대전':'DAEJEON',
    '울산':'ULSAN', '경기':'KYEONG_GI', '강원':'KANGONE', '충북':'CHUNG_BUK', '충남':'CHUNG_NAM', '전북':'JEON_BUK',
    '전남':'JEON_NAM', '경북':'KYUNG_BUK','경남':'KYUNG_NAM','제주':'JE_JU','세종':'SEJONG'}
    
    CURRENTTIME = datetime.datetime.today()
    CURRENTTIME = int(CURRENTTIME.strftime('%m'))
    globals()[f'{aa}DF'] = pd.DataFrame()
    for yy in [2020, 2021]:
        for mm in range (1, 13):
            if yy == 2020 and mm < 4 or yy == 2021 and mm > CURRENTTIME :
                print(f'{yy}{str(mm).zfill(2)} fail')
            else:    
                temp = excelappend(aa, str(yy), str(mm).zfill(2))
                globals()[f'{aa}DF'] = globals()[f'{aa}DF'].append(temp, ignore_index=True)
                print(f'{aa} {yy}{str(mm).zfill(2)} success')

    globals()[f'{aa}DF'].sort_values( by = '날짜', ascending=False, inplace=True)
    save_PATH = f'C:/Users/ad/Desktop/test/tot/KOR_{aa}' # 저장경로
    globals()[f'{aa}DF'].to_excel(save_PATH + '.xlsx', index=False)
    globals()[f'{aa}DF'].to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')
    globals()[f'{aa}DF_I'] = globals()[f'{aa}DF'].rename(RENAME_ALL, axis='columns')

# %%
for i in ['pm10', 'pm25', 'co', 'no2', 'o3', 'so2']:
    appendname(i)
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm10/202004.xls
# pm10 202004 success
# C:/Users/minipojectweb/data/pm10/202005.xls
# pm10 202005 success
# C:/Users/minipojectweb/data/pm10/202006.xls
# pm10 202006 success
# C:/Users/minipojectweb/data/pm10/202007.xls
# pm10 202007 success
# C:/Users/minipojectweb/data/pm10/202008.xls
# pm10 202008 success
# C:/Users/minipojectweb/data/pm10/202009.xls
# no2 202011 success
# C:/Users/minipojectweb/data/no2/202012.xls
# no2 202012 success
# C:/Users/minipojectweb/data/no2/202101.xls
# no2 202101 success
# C:/Users/minipojectweb/data/no2/202102.xls
# no2 202102 success
# C:/Users/minipojectweb/data/no2/202103.xls
# no2 202103 success
# C:/Users/minipojectweb/data/no2/202104.xls
# no2 202104 success
# C:/Users/minipojectweb/data/no2/202105.xls
# no2 202105 success
# C:/Users/minipojectweb/data/no2/202106.xls
# no2 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/o3/202004.xls
# o3 202004 success
# C:/Users/minipojectweb/data/o3/202005.xls
# o3 202005 success
# C:/Users/minipojectweb/data/o3/202006.xls
# o3 202006 success
# C:/Users/minipojectweb/data/o3/202007.xls
# o3 202007 success
# C:/Users/minipojectweb/data/o3/202008.xls
# o3 202008 success
# C:/Users/minipojectweb/data/o3/202009.xls
# o3 202009 success
# C:/Users/minipojectweb/data/o3/202010.xls
# o3 202010 success
# C:/Users/minipojectweb/data/o3/202011.xls
# o3 202011 success
# C:/Users/minipojectweb/data/o3/202012.xls
# o3 202012 success
# C:/Users/minipojectweb/data/o3/202101.xls
# o3 202101 success
# C:/Users/minipojectweb/data/o3/202102.xls
# o3 202102 success
# C:/Users/minipojectweb/data/o3/202103.xls
# o3 202103 success
# C:/Users/minipojectweb/data/o3/202104.xls
# o3 202104 success
# C:/Users/minipojectweb/data/o3/202105.xls
# o3 202105 success
# C:/Users/minipojectweb/data/o3/202106.xls
# o3 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/so2/202004.xls
# so2 202004 success
# C:/Users/minipojectweb/data/so2/202005.xls
# so2 202005 success
# C:/Users/minipojectweb/data/so2/202006.xls
# so2 202006 success
# C:/Users/minipojectweb/data/so2/202007.xls
# so2 202007 success
# C:/Users/minipojectweb/data/so2/202008.xls
# so2 202008 success
# C:/Users/minipojectweb/data/so2/202009.xls
# so2 202009 success
# C:/Users/minipojectweb/data/so2/202010.xls
# so2 202010 success
# C:/Users/minipojectweb/data/so2/202011.xls
# so2 202011 success
# C:/Users/minipojectweb/data/so2/202012.xls
# so2 202012 success
# C:/Users/minipojectweb/data/so2/202101.xls
# so2 202101 success
# C:/Users/minipojectweb/data/so2/202102.xls
# so2 202102 success
# C:/Users/minipojectweb/data/so2/202103.xls
# so2 202103 success
# C:/Users/minipojectweb/data/so2/202104.xls
# so2 202104 success
# C:/Users/minipojectweb/data/so2/202105.xls
# so2 202105 success
# C:/Users/minipojectweb/data/so2/202106.xls
# so2 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail

# %%
def cutcity(what):
    for city in globals()[f'{what}DF_I'].columns[1:]:
        globals()[f'{what}{city}DF_II'] = globals()[f'{what}DF_I'][ [ '날짜',city ] ].rename({ city: what}, axis='columns')

pm10DF_I.columns
# Out:
# Index(['날짜', 'SEOUL', 'PUSAN', 'DEAGU', 'INCHEON', 'KWANG_JU', 'DAEJEON',
#        'ULSAN', 'KYEONG_GI', 'KANGONE', 'CHUNG_BUK', 'CHUNG_NAM', 'JEON_BUK',
#        'JEON_NAM', 'KYUNG_BUK', 'KYUNG_NAM', 'JE_JU', 'SEJONG'],
#       dtype='object')

# %%
append_list = ['pm10', 'pm25', 'co', 'no2', 'o3', 'so2']
for i in append_list:
    cutcity(i)

# %%
def mergecity(what, afterwhat):
    for city in globals()[f'{what}DF_I'].columns[1:]:
        globals()[f'{what}{city}DF_II'] = pd.merge(left = globals()[f'{what}{city}DF_II'], right = globals()[f'{afterwhat}{city}DF_II'], how = 'left', left_on ='날짜', right_on='날짜')
        globals()[f'{what}{city}DF_II'].drop_duplicates() # 중복 행제거 모든열기준
        globals()[f'{what}{city}DF_II'].sort_values( by = '날짜', ascending=False, inplace=True)
        pppath    = f'{city}_FIN'
        save_PATH = f'C:/Users/ad/Desktop/test/{pppath}'
        globals()[f'{what}{city}DF_II'].to_excel(save_PATH + '.xlsx', index=False)
        globals()[f'{what}{city}DF_II'].to_csv(save_PATH + '.csv', index=False, encoding='utf-8-sig')

# %%
append_list = ['pm25', 'co', 'no2', 'o3', 'so2']
for what in ['pm10']:
    pass
    for afterwhat in append_list:
        mergecity(what, afterwhat)

# %%
append_list = ['pm10', 'pm25', 'co', 'no2', 'o3', 'so2']

for i in append_list:
    appendname(i)
    print(i)
for i in append_list:
    cutcity(i)
# Out:
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm10/202004.xls
# pm10 202004 success
# C:/Users/minipojectweb/data/pm10/202005.xls
# pm10 202005 success
# C:/Users/minipojectweb/data/pm10/202006.xls
# pm10 202006 success
# C:/Users/minipojectweb/data/pm10/202007.xls
# pm10 202007 success
# C:/Users/minipojectweb/data/pm10/202008.xls
# pm10 202008 success
# C:/Users/minipojectweb/data/pm10/202009.xls
# pm10 202009 success
# C:/Users/minipojectweb/data/pm10/202010.xls
# pm10 202010 success
# C:/Users/minipojectweb/data/pm10/202011.xls
# pm10 202011 success
# C:/Users/minipojectweb/data/pm10/202012.xls
# pm10 202012 success
# C:/Users/minipojectweb/data/pm10/202101.xls
# pm10 202101 success
# C:/Users/minipojectweb/data/pm10/202102.xls
# pm10 202102 success
# C:/Users/minipojectweb/data/pm10/202103.xls
# pm10 202103 success
# C:/Users/minipojectweb/data/pm10/202104.xls
# pm10 202104 success
# C:/Users/minipojectweb/data/pm10/202105.xls
# pm10 202105 success
# C:/Users/minipojectweb/data/pm10/202106.xls
# pm10 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# pm10
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/pm25/202004.xls
# pm25 202004 success
# C:/Users/minipojectweb/data/pm25/202005.xls
# pm25 202005 success
# C:/Users/minipojectweb/data/pm25/202006.xls
# pm25 202006 success
# C:/Users/minipojectweb/data/pm25/202007.xls
# pm25 202007 success
# C:/Users/minipojectweb/data/pm25/202008.xls
# pm25 202008 success
# C:/Users/minipojectweb/data/pm25/202009.xls
# pm25 202009 success
# C:/Users/minipojectweb/data/pm25/202010.xls
# pm25 202010 success
# C:/Users/minipojectweb/data/pm25/202011.xls
# pm25 202011 success
# C:/Users/minipojectweb/data/pm25/202012.xls
# pm25 202012 success
# C:/Users/minipojectweb/data/pm25/202101.xls
# pm25 202101 success
# C:/Users/minipojectweb/data/pm25/202102.xls
# pm25 202102 success
# C:/Users/minipojectweb/data/pm25/202103.xls
# pm25 202103 success
# C:/Users/minipojectweb/data/pm25/202104.xls
# pm25 202104 success
# C:/Users/minipojectweb/data/pm25/202105.xls
# pm25 202105 success
# C:/Users/minipojectweb/data/pm25/202106.xls
# pm25 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# o3
# 202001 fail
# 202002 fail
# 202003 fail
# C:/Users/minipojectweb/data/so2/202004.xls
# so2 202004 success
# C:/Users/minipojectweb/data/so2/202005.xls
# so2 202005 success
# C:/Users/minipojectweb/data/so2/202006.xls
# so2 202006 success
# C:/Users/minipojectweb/data/so2/202007.xls
# so2 202007 success
# C:/Users/minipojectweb/data/so2/202008.xls
# so2 202008 success
# C:/Users/minipojectweb/data/so2/202009.xls
# so2 202009 success
# C:/Users/minipojectweb/data/so2/202010.xls
# so2 202010 success
# C:/Users/minipojectweb/data/so2/202011.xls
# so2 202011 success
# C:/Users/minipojectweb/data/so2/202012.xls
# so2 202012 success
# C:/Users/minipojectweb/data/so2/202101.xls
# so2 202101 success
# C:/Users/minipojectweb/data/so2/202102.xls
# so2 202102 success
# C:/Users/minipojectweb/data/so2/202103.xls
# so2 202103 success
# C:/Users/minipojectweb/data/so2/202104.xls
# so2 202104 success
# C:/Users/minipojectweb/data/so2/202105.xls
# so2 202105 success
# C:/Users/minipojectweb/data/so2/202106.xls
# so2 202106 success
# 202107 fail
# 202108 fail
# 202109 fail
# 202110 fail
# 202111 fail
# 202112 fail
# so2

# %%
append_list = ['pm25', 'co', 'no2', 'o3', 'so2']
for afterwhat in append_list:
    mergecity('pm10', afterwhat)
# Out:
#              날짜  pm10  pm25
# 0    2021-06-21    56    34
# 1    2021-06-20    51    31
# 2    2021-06-19    42    26
# 3    2021-06-18    17    11
# 4    2021-06-17    17     8
# ..          ...   ...   ...
# 442  2020-04-05    47    22
# 443  2020-04-04    68    27
# 444  2020-04-03    56    32
# 445  2020-04-02    39    24
# 446  2020-04-01    69    30
#
# [447 rows x 3 columns]
#              날짜  pm25
# 426  2021-06-21    34
# 427  2021-06-20    31
# 428  2021-06-19    26
# 429  2021-06-18    11
# 430  2021-06-17     8
# ..          ...   ...
# 25   2020-04-05    22
# 26   2020-04-04    27
# 27   2020-04-03    32
# 28   2020-04-02    24
# 29   2020-04-01    30
#
# [447 rows x 2 columns]
#              날짜  pm10  pm25   co
# 0    2021-06-21    56    34  0.5
# 1    2021-06-20    51    31  0.5
# 2    2021-06-19    42    26  0.5
# 3    2021-06-18    17    11  0.3
# 4    2021-06-17    17     8  0.3
# ..          ...   ...   ...  ...
# 442  2020-04-05    47    22  0.4
# 443  2020-04-04    68    27  0.4
# 444  2020-04-03    56    32  0.5
# 445  2020-04-02    39    24  0.5
# 446  2020-04-01    69    30  0.5
#
# [447 rows x 4 columns]
#              날짜   co
# 426  2021-06-21  0.5
# 427  2021-06-20  0.5
# 428  2021-06-19  0.5
# 429  2021-06-18  0.3
# 430  2021-06-17  0.3
# ..          ...  ...
# 25   2020-04-05  0.4
# 26   2020-04-04  0.4
# 27   2020-04-03  0.5
# 28   2020-04-02  0.5
# 29   2020-04-01  0.5
#
# [447 rows x 2 columns]
#              날짜  pm10  pm25   co    no2
# 0    2021-06-21    56    34  0.5  0.011
# 1    2021-06-20    51    31  0.5  0.014
# 2    2021-06-19    42    26  0.5  0.016
# 3    2021-06-18    17    11  0.3  0.015
# 4    2021-06-17    17     8  0.3  0.016
# ..          ...   ...   ...  ...    ...
# 442  2020-04-05    47    22  0.4  0.015
# 443  2020-04-04    68    27  0.4  0.015
