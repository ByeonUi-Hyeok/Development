# %%
# 0. 모듈 설치
# !pip install bs4
# !pip install html5lib

# %%
# 1. 모듈 가져오기(import)
from bs4 import BeautifulSoup
from urllib.request import  urlopen
import html5lib
import time

# %%
# 2. 타겟 사이트 지정
target_site1 =  'https://www.airkorea.or.kr/web/sidoQualityCompare?itemCode=10008&pMENU_NO=102'
target_site1
# Out:
# 'https://www.airkorea.or.kr/web/sidoQualityCompare?itemCode=10008&pMENU_NO=102'

# %%
# 사이트에 들어가면 서버가 html,css,js등을 내려주고 브라우저는 그걸 해석(파싱)해서 화면에 띄워줌
# 3. 접속(요청)하여 html, css, js를 다운받는다.
res1 = urlopen( target_site1 ) #이 부분은 브라우저를 띄우고 주소 치고엔터쳐서 화면이 보이기 직전과 동일하다.
res1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b4b1e65802d0> in <module>
#       1 # 사이트에 들어가면 서버가 html,css,js등을 내려주고 브라우저는 그걸 해석(파싱)해서 화면에 띄워줌
#       2 # 3. 접속(요청)하여 html, css, js를 다운받는다.
# ----> 3 res1 = urlopen( target_site1 ) #이 부분은 브라우저를 띄우고 주소 치고엔터쳐서 화면이 보이기 직전과 동일하다.
#       4 res1
#
# NameError: name 'target_site1' is not defined

# %%
soup1 = BeautifulSoup(res1, 'html.parser')

# %%
soup1

# %%
# !pip install selenium
# 웹조작을 위한 셀레니움 라이브러리 설치

# %%
from selenium import webdriver
# 셀레니움 모듈 가져오기
from bs4 import BeautifulSoup

# %%
CR_PATH = 'C:/Users/chromedriver.exe'  # chromedriver 경로 설정
target_url_1 = 'https://www.airkorea.or.kr/web/sidoQualityCompare?itemCode=10008&pMENU_NO=102' # 타겟사이트 지정

# %%
CR_DRIVER = webdriver.Chrome(CR_PATH) # 셀리니움 크롬드라이버 실행R_DRIVER = webdriver.Chrome(CR_PATH) # 셀리니움 크롬드라이버 실행
CR_DRIVER.get(target_url_1) # target_url_1로접속
html_DL = CR_DRIVER.page_source #해당페이지 html 다운로드

# %%
after_ps = BeautifulSoup(html_DL, 'html.parser')

# %%
after_ps.select('#month > option')
after_ps.find_
# Out:
# [<option value="202004">2020년 04월</option>,
#  <option value="202005">2020년 05월</option>,
#  <option value="202006">2020년 06월</option>,
#  <option value="202007">2020년 07월</option>,
#  <option value="202008">2020년 08월</option>,
#  <option value="202009">2020년 09월</option>,
#  <option value="202010">2020년 10월</option>,
#  <option value="202011">2020년 11월</option>,
#  <option value="202012">2020년 12월</option>,
#  <option value="202101">2021년 01월</option>,
#  <option value="202102">2021년 02월</option>,
#  <option value="202103">2021년 03월</option>,
#  <option value="202104">2021년 04월</option>,
#  <option value="202105">2021년 05월</option>,
#  <option value="202106">2021년 06월</option>]

# %%
import datetime
a = datetime.datetime.today()
a = a.strftime('%Y%m-%H:%M')
a
# Out:
# '202106-16:56'

# %%
CR_DRIVER.find_element_by_id('month')
CR_DRIVER
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4e733c00028b343454b0b8691b766607", element="d29a0b62-656b-400c-a130-6bb971b0993d")>

# %%
CR_DRIVER.find_element_by_css_selector('%month')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\miniconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\miniconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# ...

# %%
CR_DRIVER.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\miniconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\miniconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# ...

# %%
#최종
import pandas as pd 
import numpy as np
import bokeh
import webbrowser
from bokeh.io import output_notebook, show, save, output_notebook, curdoc
from bokeh.plotting import figure, show
from bokeh.models import Select, CheckboxButtonGroup, ColumnDataSource, DataTable, TableColumn, WMTSTileSource
from bokeh.layouts import row, column
from bokeh.resources import INLINE
output_notebook() 




#자료임포트
filepath = f'C:/Users/ad/Desktop/test/fin/SEOULFIN.xlsx'
excel_df = pd.read_excel(filepath)
excel_df_cop = excel_df.copy()
excel_df_cop['DATE'] = pd.to_datetime(excel_df['DATE']) #date 컬럼 시계열 변경

# 체크박스 다중선택
from bokeh.models import CheckboxButtonGroup

checkbox_options = ['PM2.5','오존','머시기','머시기','머시기','머시기']

checkbox_grp = CheckboxButtonGroup(labels=checkbox_options, active=[0], button_type="success")

# 라인그래프
ap = figure(plot_width=700, plot_height=400, x_axis_type='datetime', output_backend="svg",sizing_mode='stretch_width', title='SEOUL')
ap.line(excel_df_cop['DATE'], excel_df_cop['PM2.5'], color='navy', alpha=0.5)

# 표
source = ColumnDataSource(excel_df)
columns = [ TableColumn( field=col, title=col ) for col in excel_df.columns ]
data_table = DataTable(source=source, columns = columns, background='red',width=1300,sizing_mode='scale_both' )

# 3개 병합
layout_with_widgets = column(
                            column(checkbox_grp),column(row(ap)),
                            row(column(data_table)))
#show(checkbox_grp)
#show(ap)
#show(scatter)
#show(data_table)
show(layout_with_widgets)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6fa80f93-178a-4c70-82aa-007794fed5ba" data-root-id="1062"></div>

# %%
show(layout_with_widgets)
# Out:
#   <div class="bk-root" id="4070eb22-259c-4375-a486-781363e5ee85" data-root-id="1062"></div>
